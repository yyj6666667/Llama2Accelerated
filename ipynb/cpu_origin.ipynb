# %% [markdown]
# # Run.c
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/karpathy/llama2.c/blob/master/run.ipynb)
#
# More details can be found in the [README.md](README.md) .

# %%
#@title Clone Project
# !rm -rf tem-force
# !git clone https://github.com/yyj6666667/tem-force
# !ls
# %cd tem-force
# Out:
# Cloning into 'tem-force'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 107 (delta 36), reused 91 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 1.08 MiB | 16.77 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# assets		 Makefile	   run.cu	    tem-force	     train.py
# build_msvc.bat	 model.py	   run.ipynb	    test_all.py      win.c
# configurator.py  __pycache__	   runq		    test.c	     win.h
# doc		 README.md	   runq.c	    tinystories.py
# export.py	 requirements.txt  run_version1.cu  tokenizer.bin
# improvement	 run		   run_version2.cu  tokenizer.model
# LICENSE		 run.c		   sample.py	    tokenizer.py
# /content/tem-force/tem-force

# %%
#@title Pick Your Model

#@markdown Choose model
model = "stories42M" #@param ["stories15M", "stories42M", "stories110M"]

download_url = ""

if(model == "stories15M"):
  download_url = "https://huggingface.co/karpathy/tinyllamas/resolve/main/stories15M.bin"
if(model == "stories42M"):
  download_url = "https://huggingface.co/karpathy/tinyllamas/resolve/main/stories42M.bin"
if(model == "stories110M"):
  download_url = "https://huggingface.co/karpathy/tinyllamas/resolve/main/stories110M.bin"

print(f"download_url: {download_url}")

# !wget $download_url

model_file = model + ".bin"
# Out:
# download_url: https://huggingface.co/karpathy/tinyllamas/resolve/main/stories42M.bin
# --2026-01-10 15:09:13--  https://huggingface.co/karpathy/tinyllamas/resolve/main/stories42M.bin
# Resolving huggingface.co (huggingface.co)... 3.171.171.104, 3.171.171.128, 3.171.171.65, ...
# Connecting to huggingface.co (huggingface.co)|3.171.171.104|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/64c19eb0275dc8cd7f170b8f/20ab6952f8b77338484a45f788d50ed30dfda285f9954758b75d7deefd120d26?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27stories42M.bin%3B+filename%3D%22stories42M.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1768061353&Policy=&Signature=XTCXd7y%7ECl%7ElWTTSluuxvUhIrcPtGraaJu3QHZOKlOeQRvSNzQStDScaiFBo5NMXmD%7ECC-iwEc2Nb4B68PIKIl0K-V4GwkdjVr80n6ffYRNPaz-GH2A58xnhAY55tFDiLuSNcTD6A3wJOgq1xva2kILoP8AEyDQIY1S6TJIjjLmWG-tc3LBOikAsh9mZ1CrIW79CeOaDnkIzIwKhC9cH%7EYrbZuw4NhVUmmcsQkZGr%7EeJVuN2kWXS-hzxjMIhuZdqKLZrVgay9U0YXwBO5BYZJIfwibZSAMeODhgR7e2VVGWHB1AAyKUHzH2%7EN2BYseLFa1DYMG8a-h4X8MakR-VJwQ__&Key-Pair-Id=KJLH8B0YWU4Y8M [following]
# --2026-01-10 15:09:13--  https://us.gcp.cdn.hf.co/xet-bridge-us/64c19eb0275dc8cd7f170b8f/20ab6952f8b77338484a45f788d50ed30dfda285f9954758b75d7deefd120d26?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27stories42M.bin%3B+filename%3D%22stories42M.bin%22%3B&response-content-type=application%2Foctet-stream&Expires=1768061353&Policy=&Signature=XTCXd7y%7ECl%7ElWTTSluuxvUhIrcPtGraaJu3QHZOKlOeQRvSNzQStDScaiFBo5NMXmD%7ECC-iwEc2Nb4B68PIKIl0K-V4GwkdjVr80n6ffYRNPaz-GH2A58xnhAY55tFDiLuSNcTD6A3wJOgq1xva2kILoP8AEyDQIY1S6TJIjjLmWG-tc3LBOikAsh9mZ1CrIW79CeOaDnkIzIwKhC9cH%7EYrbZuw4NhVUmmcsQkZGr%7EeJVuN2kWXS-hzxjMIhuZdqKLZrVgay9U0YXwBO5BYZJIfwibZSAMeODhgR7e2VVGWHB1AAyKUHzH2%7EN2BYseLFa1DYMG8a-h4X8MakR-VJwQ__&Key-Pair-Id=KJLH8B0YWU4Y8M
# Resolving us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)... 34.120.165.110
# Connecting to us.gcp.cdn.hf.co (us.gcp.cdn.hf.co)|34.120.165.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167020572 (159M) [application/octet-stream]
# Saving to: ‘stories42M.bin’
#
# stories42M.bin      100%[===================>] 159.28M  5.04MB/s    in 32s
#
# 2026-01-10 15:09:45 (4.98 MB/s) - ‘stories42M.bin’ saved [167020572/167020572]

# %%
#CPU;
# !make runfast
# Out:
# gcc -Ofast -o run run.c -lm
# gcc -Ofast -o runq runq.c -lm

# %% [markdown]
# 若使用 CUDA 优化，需执行nvcc -arch=compute_35 -O3 -std=c++17 -o run run.c -lm命令编译代码；若使用了 cuBLAS 库，则执行nvcc -arch=compute_35 -O3 -std=c++17 -o run run.c -lm -L/usr/local/lib64 -lcublas编译代码；若采用 AVX、OpenMP 等其他优化方法，则直接执行make run即可。

# %%
#@title Generate Stories

# Generate args
max_token = 256 #@param {type:"slider", min:32, max:1024, step:32}
temperature = 0.8 #@param {type:"slider", min:0.0, max:1, step:0.05}
top_p = 0.9 #@param {type:"slider", min:0.0, max:1.0, step:0.05}
prompt = "One day, Lily met a Shoggoth" #@param {type:"string"}

print(f"model: {model_file}, max_token: {max_token}, temperature: {temperature}, top_p: {top_p}, prompt: {prompt}")
print(f"----------------------------\n")

cmd = f'./run {model_file} -t {temperature} -p {top_p} -n {max_token} -i "{prompt}"'
# !{cmd}
# Out:
# model: stories42M.bin, max_token: 256, temperature: 0.8, top_p: 0.9, prompt: One day, Lily met a Shoggoth
# ----------------------------
#
# One day, Lily met a Shoggoth. She was so excited to meet someone who was like her. The Shoggoth was shining brightly and it made her smile. She said hello and asked what it was like.
# The Shoggoth said it was very important. It said that people must be kind, to help each other and to make things look pretty. Lily thought about this and smiled.
# Then the Shoggoth said it was time to go. It said it would be here every day and it would always be important. Lily thanked the Shoggoth and waved goodbye.
# The Shogggle smiled and said it was happy to meet Lily. She said it was nice to meet a Shoggin and they both laughed.
# Lily knew it was important to be kind and help others. She smiled and waved goodbye to the Shoggoth.
# achieved tok/s: 56.500432
